# %%
import pandas as pd               # import necessary libraries
import dask.dataframe as dd

# %%
tf = pd.read_csv("Trips_Full Data.csv")

# %%
td = pd.read_csv("Trips_by_Distance.csv")

# %%
td_dask = dd.read_csv("Trips_by_Distance.csv")
